# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/Salary_Data.csv')
df.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
df.rename(columns={'YearsExperience':'Experience'},inplace=True)

# %%
df.head()
# Out:
#    Experience   Age  Salary
# 0         1.1  21.0   39343
# 1         1.3  21.5   46205
# 2         1.5  21.7   37731
# 3         2.0  22.0   43525
# 4         2.2  22.2   39891

# %%
sns.pairplot(df)
plt.show()

# %%
df.isnull().sum()
# Out:
# Experience    0
# Age           0
# Salary        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
x=df.iloc[:,:2]
y=df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dc=DecisionTreeRegressor()
dc.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dc.score(x_train,y_train)*100
# Out:
# 100.0

# %%
dc.score(x_test,y_test)*100
# Out:
# 99.3215809220332

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(50,50))
plot_tree(dc)
plt.show()

# %%
for i in range(1,20):
  dc1=DecisionTreeRegressor(max_depth=i)
  dc1.fit(x_train,y_train)
  print(dc1.score(x_train,y_train)*100,dc1.score(x_test,y_test)*100,i)
# Out:
# 76.54160246740291 66.36890348471196 1
# 94.86903848151425 82.22901402713296 2
# 98.8965644169213 90.83106337050934 3
# 99.84188830538145 98.61232461324974 4
# 99.99665372074882 98.95153415223314 5
# 100.0 99.3215809220332 6
# 100.0 98.95153415223314 7
# 100.0 99.3215809220332 8
# 100.0 98.95153415223314 9
# 100.0 98.95153415223314 10
# 100.0 98.95153415223314 11
# 100.0 98.95153415223314 12
# 100.0 99.3215809220332 13
# 100.0 98.95153415223314 14
# 100.0 99.3215809220332 15
# 100.0 98.95153415223314 16
# 100.0 99.3215809220332 17
# 100.0 98.95153415223314 18
# 100.0 99.3215809220332 19
