# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/data.csv')
df.head()
# Out:
#    CGPA   IQ  Unnamed: 2  data1  data2  output
# 0   6.8  123         NaN   0.68   1.23       1
# 1   5.9  106         NaN   0.59   1.06       0
# 2   5.3  121         NaN   0.53   1.21       0
# 3   7.4  132         NaN   0.74   1.32       1
# 4   5.8  142         NaN   0.58   1.42       0

# %%
df.drop(columns=['Unnamed: 2','CGPA','IQ'],axis=1,inplace=True)

# %%
df
# Out:
#     data1  data2  output
# 0    0.68   1.23       1
# 1    0.59   1.06       0
# 2    0.53   1.21       0
# 3    0.74   1.32       1
# 4    0.58   1.42       0
# ..    ...    ...     ...
# 95   0.43   2.00       0
# 96   0.44   0.42       0
# 97   0.67   1.82       1
# 98   0.63   1.03       1
# 99   0.62   1.13       1
#
# [100 rows x 3 columns]

# %%
sns.scatterplot(x='data1',y='data2',data=df,hue='output')
plt.show()

# %%
x=df.drop(columns=['output'])
y=df['output']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=30)

# %%
from sklearn.svm import SVC

# %%
svc=SVC(kernel='rbf')
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
svc.score(x_test,y_test)*100
# Out:
# 90.0

# %%
svc.score(x_train,y_train)*100
# Out:
# 91.25

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=svc)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
