# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('salary.csv')
df
# Out:
#     Level   Salary
# 0        1    4500
# 1        2    5000
# 2        3    6000
# 3        4    8000
# 4        5   11000
# ..     ...     ...
# 75      76   79000
# 76      77   80000
# 77      78   81000
# 78      79   82000
# 79      80   84000
#
# [80 rows x 2 columns]

# %%
sns.scatterplot(data=df,x="Level ",y="Salary")
plt.show()

# %%
df.corr()
# Out:
#           Level     Salary
# Level   1.000000  0.470229
# Salary  0.470229  1.000000

# %%
x=df[['Level ']]
y=df['Salary']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=2)
pf.fit(x)
x= pf.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.6389994822242857

# %%
# y= m1x1 +m2x2^2 +c
# y = -365.46789993*x1 +  11.91361307*x2^2 +38672.84549596248

# %%
lr.coef_
# Out:
# array([   0.        , -365.46789993,   11.91361307])

# %%
lr.intercept_
# Out:
# np.float64(38672.84549596248)

# %%
prd=lr.predict(x)

# %%
plt.scatter(df['Level '],df['Salary'])
plt.plot(df['Level '],prd,c='red')
plt.legend(['org','prd'])
plt.show()

# %%
test=pf.transform([[45]])
test
# Out:
# C:\Users\Classic\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[1.000e+00, 4.500e+01, 2.025e+03]])

# %%
lr.predict(test)
# Out:
# array([46351.85647246])
